# %% [markdown]
# # BulletTrade 最小示例（聚宽兼容）
# 在 `.env` 配置好数据源/券商后，可直接运行下方策略进行回测或实盘。

# %%
from jqdata import *

def initialize(context):
    set_benchmark('000300.XSHG')
    set_option('use_real_price', True)
    g.stocks = ['000001.XSHE', '600000.XSHG']
    run_daily(trade, time='10:00')

def trade(context):
    order(g.stocks[0], 100)
    order(g.stocks[1], 200)

# %% [markdown]
# 在命令行运行：
# ```bash
# bullet-trade backtest demo_strategy.py --start 2025-01-01 --end 2025-06-01
# ```
