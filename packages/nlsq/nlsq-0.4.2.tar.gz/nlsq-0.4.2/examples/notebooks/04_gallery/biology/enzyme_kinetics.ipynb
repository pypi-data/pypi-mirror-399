# %% [markdown]
# # 📘 Enzyme Kinetics: Michaelis-Menten Analysis> Fit Michaelis-Menten model to enzyme velocity data⏱️ **15-25 minutes** | 📊 **Level: ●●○ Intermediate** | 🏷️ **Biology** | 🔬 **Biochemistry**---
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/imewei/NLSQ/blob/main/examples/notebooks/04_gallery/biology/enzyme_kinetics.ipynb)

# %%
# @title Install NLSQ (run once in Colab)
import sys
if 'google.colab' in sys.modules:
    print("Running in Google Colab - installing NLSQ...")
    # !pip install -q nlsq
    print("✅ NLSQ installed successfully!")
else:
    print("Not running in Colab - assuming NLSQ is already installed")

# %% [markdown]
# ## 🔬 Domain Background**Model:** $v = \frac{V_{max}[S]}{K_m + [S]}$**Applications:** Enzyme characterization, drug screening---

# %% [markdown]
# ## Setup

# %%
# Configure matplotlib for inline plotting in VS Code/Jupyter
# MUST come before importing matplotlib
# %matplotlib inline

# %%
from IPython.display import display

# %%
import numpy as np
import jax.numpy as jnp
from nlsq import curve_fit
import matplotlib.pyplot as plt

def michaelis_menten(S, Vmax, Km):
    return Vmax * S / (Km + S)

# %% [markdown]
# ## Generate Data

# %%
Vmax_true, Km_true = 100, 50
S = np.array([1,2,5,10,20,50,100,200,500])
v_true = michaelis_menten(S, Vmax_true, Km_true)
v = v_true + np.random.normal(0, 3, len(S))

plt.plot(S, v, 'o')
plt.xlabel('[S] (µM)')
plt.ylabel('v (µM/s)')
plt.tight_layout()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_258888/3834656988.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Fit Model

# %%
popt, pcov = curve_fit(michaelis_menten, S, v, p0=[80, 40])
Vmax_fit, Km_fit = popt

print(f'Vmax: {Vmax_fit:.1f} µM/s')
print(f'Km: {Km_fit:.1f} µM')
# Out:
# INFO:nlsq.curve_fit:Starting curve fit | {'n_params': 2, 'n_data_points': 9, 'method': 'trf', 'solver': 'auto', 'batch_size': None, 'has_bounds': False, 'dynamic_sizing': False}
# INFO:nlsq.least_squares:Starting least squares optimization | {'method': 'trf', 'n_params': 2, 'loss': 'linear', 'ftol': 1e-08, 'xtol': 1e-08, 'gtol': 1e-08}
# INFO:nlsq.optimizer.trf:Starting TRF optimization (no bounds) | {'n_params': 2, 'n_residuals': 9, 'max_nfev': None}
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=0 | cost=3.777099e+02 | ‖∇f‖=4.019884e+01 | nfev=1
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=1 | cost=4.870631e+01 | ‖∇f‖=1.458575e+00 | step=8.944272e+01 | nfev=2
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=2 | cost=4.812401e+01 | ‖∇f‖=1.313146e-02 | step=8.944272e+01 | nfev=3
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=3 | cost=4.812388e+01 | ‖∇f‖=1.086084e-04 | step=8.944272e+01 | nfev=4
# PERFORMANCE:nlsq.least_squares:Timer: optimization took 1.047501s
# INFO:nlsq.least_squares:Convergence: reason=`ftol` termination condition is satisfied. | iterations=4 | final_cost=4.812388e+01 | time=1.048s | final_gradient_norm=1.4911949488133347e-06
# PERFORMANCE:nlsq.curve_fit:Timer: curve_fit took 1.477420s
# INFO:nlsq.curve_fit:Curve fit completed | {'total_time': 1.4774202759981563, 'final_cost': 96.24776675487983, 'covariance_warning': False}
# Vmax: 99.9 µM/s
# Km: 47.5 µM

# %% [markdown]
# ## Key Insights1. **Km indicates affinity** - Lower Km = higher substrate affinity2. **Vmax depends on enzyme amount**---
