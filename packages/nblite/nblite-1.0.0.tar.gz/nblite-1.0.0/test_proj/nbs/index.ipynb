# %% [markdown]
# # Test Project
#
# This is a test project for nblite that demonstrates the notebook-driven development workflow.
#
# ## Features Demonstrated
#
# - Basic code export with `#|export` directive
# - Function notebook export with `#|export_as_func`
# - Submodule organization
# - Various directives (`#|hide`, `#|eval: false`, etc.)

# %%
#|eval: false
# This cell demonstrates code that will appear in the README
from my_lib import core

# Use the greet function
core.greet("World")

# %% [markdown]
# ## Installation
#
# ```bash
# pip install test-proj
# ```

# %%
#|hide
# This cell will be hidden from README
print("This won't appear in the README")
# Out:
# This won't appear in the README
