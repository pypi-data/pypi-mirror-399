# %% [markdown]
# # Building a JointDb: Integrating Hi-C Embeddings with Epigenomic Signal Tracks
#
# This notebook demonstrates how to create a `JointDb` database that integrates Hi-C embeddings from `jointly-hic` with additional epigenomic datasets, such as ChIP-seq signal tracks.
#
# ## What is JointDb?
#
# `JointDb` is an optional output format of the `jointly-hic` toolkit. It is a compact HDF5-based database that combines:
# - Low-dimensional Hi-C embeddings (e.g., PCA or NMF coordinates)
# - Sample metadata (e.g., biosample, cell type, condition)
# - BigWig signal tracks from ChIP-seq, ATAC-seq, or RNA-seq
#
# This unified format enables:
# - Efficient storage and query of per-bin signal and embedding data
# - Integration of 3D chromatin structure with regulatory activity
# - Visualization and analysis across genomic regions and samples
#
# ## Overview of This Notebook
#
# In this example, we use public CD4+ and CD8+ T cell Hi-C data from ENCODE and enrich it with H3K27ac ChIP-seq signal tracks.
#
# We will:
# 1. Load and annotate post-processed Hi-C embeddings (`.pq`) with sample metadata
# 2. Generate experiment and track metadata files in YAML format
# 3. Create a `JointDb` HDF5 file combining all datasets
#
# ## Input Files
#
# - `HiC-metadata.txt`: Metadata table for CD4+/CD8+ Hi-C samples (ENCODE accessions, biosample info)
# - `ChIP-metadata.csv`: Metadata for matched ChIP-seq experiments (e.g., H3K27ac)
# - `t-cell-demo-output_PCA-32_80000bp_hg38_post_processed.pq`: Post-processed Hi-C embeddings
# - BigWig files: Referenced in the ChIP-seq metadata and automatically retrieved
#
# ## Output
#
# - `t-cell-demo-annotated.pq`: Embeddings with merged sample metadata
# - `experiment-metadata.yaml`: YAML describing Hi-C experiments
# - `track-metadata.yaml`: YAML describing ChIP-seq signal tracks
# - `t-cell-jointdb.h5`: The final JointDb HDF5 database
#
# With this setup, you can analyze or visualize how chromatin structure (via Hi-C embeddings) correlates with epigenetic features across T cell types and genomic loci.

# %%
import pandas as pd

# %%
# Path to the "post processed" jointly embeddings
EMBEDDINGS = "./data/t-cell-demo-output_PCA-32_80000bp_hg38_post_processed.pq"

# Load the embeddings
df = pd.read_parquet(EMBEDDINGS)
df.head()
# Out:
#   chrom   start     end  weight  good_bin                filename  PCA1  PCA2  \
# 0  chr1       0   80000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 1  chr1   80000  160000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 2  chr1  160000  240000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 3  chr1  240000  320000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 4  chr1  320000  400000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
#
#    PCA3  PCA4  ...  leiden_0_3_n500  leiden_0_5_n500  leiden_0_8_n500  \
# 0   NaN   NaN  ...              NaN              NaN              NaN
# 1   NaN   NaN  ...              NaN              NaN              NaN
# 2   NaN   NaN  ...              NaN              NaN              NaN
# 3   NaN   NaN  ...              NaN              NaN              NaN
# 4   NaN   NaN  ...              NaN              NaN              NaN
#
#    leiden_1_0_n500  umap1_n30  umap2_n30  umap1_n100  umap2_n100  umap1_n500  \
# 0              NaN        NaN        NaN         NaN         NaN         NaN
# 1              NaN        NaN        NaN         NaN         NaN         NaN
# 2              NaN        NaN        NaN         NaN         NaN         NaN
# 3              NaN        NaN        NaN         NaN         NaN         NaN
# 4              NaN        NaN        NaN         NaN         NaN         NaN
#
#    umap2_n500
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 60 columns]

# %%
# Load metadata describing ENCODE CD4+/CD8+ Hi-C experiments
meta = pd.read_csv("HiC-metadata.txt", sep="\t")
meta
# Out:
#      accession assay_term_name  assay_title  \
# 0  ENCSR351NAI             HiC  intact Hi-C
# 1  ENCSR923PPH             HiC  intact Hi-C
# 2  ENCSR321BHC             HiC  intact Hi-C
# 3  ENCSR215PTV             HiC  intact Hi-C
# 4  ENCSR335JYP             HiC  intact Hi-C
# 5  ENCSR379TIE             HiC  intact Hi-C
# 6  ENCSR421CGL             HiC  intact Hi-C
# 7  ENCSR195ETV             HiC  intact Hi-C
# 8  ENCSR458VJJ             HiC  intact Hi-C
# 9  ENCSR291EBI             HiC  intact Hi-C
#
#                                            biosample  \
# 0          activated CD8-positive, alpha-beta T cell
# 1          activated CD4-positive, alpha-beta T cell
# 2                    CD8-positive, alpha-beta T cell
# 3  naive thymus-derived CD4-positive, alpha-beta ...
# 4                    CD4-positive, alpha-beta T cell
# 5             CD4-positive, alpha-beta memory T cell
# 6          activated CD4-positive, alpha-beta T cell
# 7    activated naive CD4-positive, alpha-beta T cell
# 8  naive thymus-derived CD4-positive, alpha-beta ...
# 9   activated CD4-positive, alpha-beta memory T cell
#
#                                    biosample_summary hic_accession
# 0  Homo sapiens activated CD8-positive, alpha-bet...   ENCFF493SFI
# 1  Homo sapiens activated CD4-positive, alpha-bet...   ENCFF355VJW
# 2  Homo sapiens CD8-positive, alpha-beta T cell m...   ENCFF009ONH
# 3  Homo sapiens naive thymus-derived CD4-positive...   ENCFF520GFL
# 4  Homo sapiens CD4-positive, alpha-beta T cell m...   ENCFF958DWQ
# 5  Homo sapiens CD4-positive, alpha-beta memory T...   ENCFF442IGJ
# 6  Homo sapiens activated CD4-positive, alpha-bet...   ENCFF962EDB
# 7  Homo sapiens activated naive CD4-positive, alp...   ENCFF571GTF
# 8  Homo sapiens naive thymus-derived CD4-positive...   ENCFF044TCQ
# 9  Homo sapiens activated CD4-positive, alpha-bet...   ENCFF980NXK

# %%
# We need to extract the "hic_accession" from the "filename" and then merge the metadata
# Split at "/" and "." to get the accession value
df["hic_accession"] = df["filename"].map(lambda x: x.split("/")[1].split(".")[0])

# %%
# Merge the metadata into the dataframe
df = pd.merge(df, meta)
df.head()
# Out:
#   chrom   start     end  weight  good_bin                filename  PCA1  PCA2  \
# 0  chr1       0   80000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 1  chr1   80000  160000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 2  chr1  160000  240000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 3  chr1  240000  320000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
# 4  chr1  320000  400000     NaN     False  data/ENCFF009ONH.mcool   NaN   NaN
#
#    PCA3  PCA4  ...  umap1_n100  umap2_n100  umap1_n500  umap2_n500  \
# 0   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 1   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 2   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 3   NaN   NaN  ...         NaN         NaN         NaN         NaN
# 4   NaN   NaN  ...         NaN         NaN         NaN         NaN
#
#    hic_accession    accession  assay_term_name  assay_title  \
# 0    ENCFF009ONH  ENCSR321BHC              HiC  intact Hi-C
# 1    ENCFF009ONH  ENCSR321BHC              HiC  intact Hi-C
# 2    ENCFF009ONH  ENCSR321BHC              HiC  intact Hi-C
# 3    ENCFF009ONH  ENCSR321BHC              HiC  intact Hi-C
# 4    ENCFF009ONH  ENCSR321BHC              HiC  intact Hi-C
#
#                          biosample  \
# 0  CD8-positive, alpha-beta T cell
# 1  CD8-positive, alpha-beta T cell
# 2  CD8-positive, alpha-beta T cell
# 3  CD8-positive, alpha-beta T cell
# 4  CD8-positive, alpha-beta T cell
#
#                                    biosample_summary
# 0  Homo sapiens CD8-positive, alpha-beta T cell m...
# 1  Homo sapiens CD8-positive, alpha-beta T cell m...
# 2  Homo sapiens CD8-positive, alpha-beta T cell m...
# 3  Homo sapiens CD8-positive, alpha-beta T cell m...
# 4  Homo sapiens CD8-positive, alpha-beta T cell m...
#
# [5 rows x 66 columns]

# %%
# Save the embeddings with metadata
df.to_parquet("./data/t-cell-demo-annotated.pq")

# %%
# Now, we can extract the metadata as YAML to make the JointDb database
! jointly embedding2yaml --parquet-file ./data/t-cell-demo-annotated.pq \
    --accession-column hic_accession \
    --metadata-columns biosample biosample_summary \
    --yaml-file experiment-metadata.yaml
# Out:
# 2025-04-09 10:37:31,329::INFO::main:   Starting joint PCA
# 2025-04-09 10:37:31,803::INFO::main:   Metadata successfully written to experiment-metadata.yaml
# 2025-04-09 10:37:31,806::INFO::main:   Finished joint PCA

# %%
# Let's also prepare our track metadata from ChIP-metadata.csv
# This file must contain only the following columns: biosample, assay, experiment, accession
! jointly tracks2yaml ChIP-metadata.csv track-metadata.yaml
# Out:
# 2025-04-09 10:37:32,589::INFO::main:   Starting joint PCA
# 2025-04-09 10:37:32,600::INFO::main:   Finished joint PCA

# %%
# Now we can create a JointDb database
! jointly hdf5db --experiments experiment-metadata.yaml \
    --tracks track-metadata.yaml \
    --embeddings ./data/t-cell-demo-annotated.pq \
    --accession hic_accession \
    --output data/t-cell-jointdb.h5
# Out:
# 2025-04-09 10:37:33,307::INFO::main:   Starting joint PCA
# 2025-04-09 10:37:33,307::INFO::main:   Creating HDF5 file at data/t-cell-jointdb.h5
# 2025-04-09 10:37:33,347::INFO::create_hdf5:   HDF5 file created at data/t-cell-jointdb.h5
# 2025-04-09 10:37:33,347::INFO::main:   Loading and storing bins...
# 2025-04-09 10:37:33,720::INFO::store_bins:   Bin information stored successfully.
# 2025-04-09 10:37:33,721::INFO::main:   Loading and storing experiment metadata...
# 2025-04-09 10:37:33,725::INFO::store_experiment_metadata:   Experiment metadata stored successfully.
# 2025-04-09 10:37:33,725::INFO::main:   Loading and storing embeddings...
# 2025-04-09 10:37:35,721::INFO::store_embeddings:   [1/52] Storing embeddings for PCA1.
# 2025-04-09 10:37:36,244::INFO::store_embeddings:   [2/52] Storing embeddings for PCA2.
# 2025-04-09 10:37:36,762::INFO::store_embeddings:   [3/52] Storing embeddings for PCA3.
# 2025-04-09 10:37:37,278::INFO::store_embeddings:   [4/52] Storing embeddings for PCA4.
# 2025-04-09 10:37:37,813::INFO::store_embeddings:   [5/52] Storing embeddings for PCA5.
# 2025-04-09 10:37:38,326::INFO::store_embeddings:   [6/52] Storing embeddings for PCA6.
# 2025-04-09 10:37:38,861::INFO::store_embeddings:   [7/52] Storing embeddings for PCA7.
# 2025-04-09 10:37:39,371::INFO::store_embeddings:   [8/52] Storing embeddings for PCA8.
# 2025-04-09 10:37:39,906::INFO::store_embeddings:   [9/52] Storing embeddings for PCA9.
# 2025-04-09 10:37:40,416::INFO::store_embeddings:   [10/52] Storing embeddings for PCA10.
# 2025-04-09 10:37:40,951::INFO::store_embeddings:   [11/52] Storing embeddings for PCA11.
# 2025-04-09 10:37:41,461::INFO::store_embeddings:   [12/52] Storing embeddings for PCA12.
# 2025-04-09 10:37:41,997::INFO::store_embeddings:   [13/52] Storing embeddings for PCA13.
# 2025-04-09 10:37:42,508::INFO::store_embeddings:   [14/52] Storing embeddings for PCA14.
# 2025-04-09 10:37:43,044::INFO::store_embeddings:   [15/52] Storing embeddings for PCA15.
# 2025-04-09 10:37:43,556::INFO::store_embeddings:   [16/52] Storing embeddings for PCA16.
# 2025-04-09 10:37:44,091::INFO::store_embeddings:   [17/52] Storing embeddings for PCA17.
# 2025-04-09 10:37:44,603::INFO::store_embeddings:   [18/52] Storing embeddings for PCA18.
# 2025-04-09 10:37:45,140::INFO::store_embeddings:   [19/52] Storing embeddings for PCA19.
# 2025-04-09 10:37:45,653::INFO::store_embeddings:   [20/52] Storing embeddings for PCA20.
# 2025-04-09 10:37:46,188::INFO::store_embeddings:   [21/52] Storing embeddings for PCA21.
# 2025-04-09 10:37:46,700::INFO::store_embeddings:   [22/52] Storing embeddings for PCA22.
# 2025-04-09 10:37:47,237::INFO::store_embeddings:   [23/52] Storing embeddings for PCA23.
# 2025-04-09 10:37:47,750::INFO::store_embeddings:   [24/52] Storing embeddings for PCA24.
# 2025-04-09 10:37:48,287::INFO::store_embeddings:   [25/52] Storing embeddings for PCA25.
# 2025-04-09 10:37:48,799::INFO::store_embeddings:   [26/52] Storing embeddings for PCA26.
# 2025-04-09 10:37:49,338::INFO::store_embeddings:   [27/52] Storing embeddings for PCA27.
# 2025-04-09 10:37:49,852::INFO::store_embeddings:   [28/52] Storing embeddings for PCA28.
# 2025-04-09 10:37:50,390::INFO::store_embeddings:   [29/52] Storing embeddings for PCA29.
# 2025-04-09 10:37:50,904::INFO::store_embeddings:   [30/52] Storing embeddings for PCA30.
# 2025-04-09 10:37:51,443::INFO::store_embeddings:   [31/52] Storing embeddings for PCA31.
# 2025-04-09 10:37:51,957::INFO::store_embeddings:   [32/52] Storing embeddings for PCA32.
# 2025-04-09 10:37:52,494::INFO::store_embeddings:   [33/52] Storing embeddings for kmeans_5.
# 2025-04-09 10:37:53,009::INFO::store_embeddings:   [34/52] Storing embeddings for kmeans_6.
# 2025-04-09 10:37:53,548::INFO::store_embeddings:   [35/52] Storing embeddings for kmeans_7.
# 2025-04-09 10:37:54,062::INFO::store_embeddings:   [36/52] Storing embeddings for kmeans_8.
# 2025-04-09 10:37:54,602::INFO::store_embeddings:   [37/52] Storing embeddings for kmeans_9.
# 2025-04-09 10:37:55,119::INFO::store_embeddings:   [38/52] Storing embeddings for kmeans_10.
# 2025-04-09 10:37:55,657::INFO::store_embeddings:   [39/52] Storing embeddings for kmeans_15.
# 2025-04-09 10:37:56,172::INFO::store_embeddings:   [40/52] Storing embeddings for kmeans_20.
# 2025-04-09 10:37:56,711::INFO::store_embeddings:   [41/52] Storing embeddings for leiden_0_1_n500.
# 2025-04-09 10:37:57,226::INFO::store_embeddings:   [42/52] Storing embeddings for leiden_0_2_n500.
# 2025-04-09 10:37:57,766::INFO::store_embeddings:   [43/52] Storing embeddings for leiden_0_3_n500.
# 2025-04-09 10:37:58,280::INFO::store_embeddings:   [44/52] Storing embeddings for leiden_0_5_n500.
# 2025-04-09 10:37:58,819::INFO::store_embeddings:   [45/52] Storing embeddings for leiden_0_8_n500.
# 2025-04-09 10:37:59,335::INFO::store_embeddings:   [46/52] Storing embeddings for leiden_1_0_n500.
# 2025-04-09 10:37:59,874::INFO::store_embeddings:   [47/52] Storing embeddings for umap1_n30.
# 2025-04-09 10:38:00,389::INFO::store_embeddings:   [48/52] Storing embeddings for umap2_n30.
# 2025-04-09 10:38:00,928::INFO::store_embeddings:   [49/52] Storing embeddings for umap1_n100.
# 2025-04-09 10:38:01,443::INFO::store_embeddings:   [50/52] Storing embeddings for umap2_n100.
# 2025-04-09 10:38:01,982::INFO::store_embeddings:   [51/52] Storing embeddings for umap1_n500.
# 2025-04-09 10:38:02,498::INFO::store_embeddings:   [52/52] Storing embeddings for umap2_n500.
# 2025-04-09 10:38:03,042::INFO::main:   Loading and storing track metadata and tracks...
# 2025-04-09 10:38:03,059::INFO::add_encode_tracks_to_hdf5:   Adding 68 tracks to the HDF5 file data/t-cell-jointdb.h5
# 2025-04-09 10:38:04,688::INFO::process_entry:   Loading signal for track: ENCFF446TSX
# 2025-04-09 10:38:04,689::INFO::process_entry:   Loading signal for track: ENCFF853MDG
# 2025-04-09 10:38:04,690::INFO::process_entry:   Loading signal for track: ENCFF602PAL
# 2025-04-09 10:38:04,690::INFO::process_entry:   Loading signal for track: ENCFF078XQO
# 2025-04-09 10:38:04,691::INFO::process_entry:   Loading signal for track: ENCFF727UVG
# 2025-04-09 10:38:04,692::INFO::process_entry:   Loading signal for track: ENCFF153OTG
# 2025-04-09 10:38:04,692::INFO::process_entry:   Loading signal for track: ENCFF983MZP
# 2025-04-09 10:38:04,693::INFO::process_entry:   Loading signal for track: ENCFF371PQB
# 2025-04-09 10:38:18,881::INFO::process_entry:   Loading signal for track: ENCFF773LSR
# 2025-04-09 10:38:23,869::INFO::add_encode_tracks_to_hdf5:   [1/68] Adding track ENCFF446TSX to HDF5 file.
# 2025-04-09 10:38:23,870::INFO::process_entry:   Loading signal for track: ENCFF599VAD
# 2025-04-09 10:38:28,506::INFO::process_entry:   Loading signal for track: ENCFF902LSI
# 2025-04-09 10:38:28,506::INFO::process_entry:   Loading signal for track: ENCFF134OLO
# 2025-04-09 10:38:32,858::INFO::process_entry:   Loading signal for track: ENCFF921FOC
# 2025-04-09 10:38:41,345::INFO::add_encode_tracks_to_hdf5:   [2/68] Adding track ENCFF371PQB to HDF5 file.
# 2025-04-09 10:38:46,250::INFO::process_entry:   Loading signal for track: ENCFF792DLB
# 2025-04-09 10:38:46,251::INFO::process_entry:   Loading signal for track: ENCFF218XJQ
# 2025-04-09 10:38:46,251::INFO::process_entry:   Loading signal for track: ENCFF414FEJ
# 2025-04-09 10:38:50,998::INFO::add_encode_tracks_to_hdf5:   [3/68] Adding track ENCFF983MZP to HDF5 file.
# 2025-04-09 10:38:50,998::INFO::process_entry:   Loading signal for track: ENCFF830YRD
# 2025-04-09 10:39:00,111::INFO::process_entry:   Loading signal for track: ENCFF168UFN
# 2025-04-09 10:39:00,111::INFO::process_entry:   Loading signal for track: ENCFF256WHR
# 2025-04-09 10:39:04,043::INFO::add_encode_tracks_to_hdf5:   [4/68] Adding track ENCFF078XQO to HDF5 file.
# 2025-04-09 10:39:08,366::INFO::process_entry:   Loading signal for track: ENCFF347CQB
# 2025-04-09 10:39:12,134::INFO::process_entry:   Loading signal for track: ENCFF034CTK
# 2025-04-09 10:39:12,134::INFO::process_entry:   Loading signal for track: ENCFF884OMU
# 2025-04-09 10:39:15,934::INFO::process_entry:   Loading signal for track: ENCFF295CPY
# 2025-04-09 10:39:20,007::INFO::process_entry:   Loading signal for track: ENCFF296NOR
# 2025-04-09 10:39:20,008::INFO::add_encode_tracks_to_hdf5:   [5/68] Adding track ENCFF153OTG to HDF5 file.
# 2025-04-09 10:39:24,515::INFO::process_entry:   Loading signal for track: ENCFF435MWB
# 2025-04-09 10:39:28,880::INFO::process_entry:   Loading signal for track: ENCFF853JHP
# 2025-04-09 10:39:33,252::INFO::process_entry:   Loading signal for track: ENCFF591RWC
# 2025-04-09 10:39:41,644::INFO::add_encode_tracks_to_hdf5:   [6/68] Adding track ENCFF853MDG to HDF5 file.
# 2025-04-09 10:39:41,645::INFO::process_entry:   Loading signal for track: ENCFF088KUT
# 2025-04-09 10:39:46,395::INFO::process_entry:   Loading signal for track: ENCFF087SNY
# 2025-04-09 10:39:50,256::INFO::process_entry:   Loading signal for track: ENCFF885JYJ
# 2025-04-09 10:39:50,257::INFO::process_entry:   Loading signal for track: ENCFF760SNB
# 2025-04-09 10:39:55,187::INFO::process_entry:   Loading signal for track: ENCFF193MIZ
# 2025-04-09 10:40:04,060::INFO::process_entry:   Loading signal for track: ENCFF694IFY
# 2025-04-09 10:40:04,060::INFO::process_entry:   Loading signal for track: ENCFF892JDN
# 2025-04-09 10:40:04,060::INFO::add_encode_tracks_to_hdf5:   [7/68] Adding track ENCFF727UVG to HDF5 file.
# 2025-04-09 10:40:07,883::INFO::process_entry:   Loading signal for track: ENCFF765HYA
# 2025-04-09 10:40:12,263::INFO::process_entry:   Loading signal for track: ENCFF158WCY
# 2025-04-09 10:40:16,091::INFO::process_entry:   Loading signal for track: ENCFF788JSC
# 2025-04-09 10:40:20,779::INFO::process_entry:   Loading signal for track: ENCFF190AJB
# 2025-04-09 10:40:25,365::INFO::process_entry:   Loading signal for track: ENCFF537CQL
# 2025-04-09 10:40:29,384::INFO::add_encode_tracks_to_hdf5:   [8/68] Adding track ENCFF602PAL to HDF5 file.
# 2025-04-09 10:40:33,476::INFO::process_entry:   Loading signal for track: ENCFF301EPC
# 2025-04-09 10:40:41,874::INFO::process_entry:   Loading signal for track: ENCFF061JOB
# 2025-04-09 10:40:45,696::INFO::process_entry:   Loading signal for track: ENCFF175MGD
# 2025-04-09 10:40:45,697::INFO::process_entry:   Loading signal for track: ENCFF893HGX
# 2025-04-09 10:40:50,520::INFO::process_entry:   Loading signal for track: ENCFF373LYP
# 2025-04-09 10:40:50,522::INFO::add_encode_tracks_to_hdf5:   [9/68] Adding track ENCFF773LSR to HDF5 file.
# 2025-04-09 10:40:50,526::INFO::add_encode_tracks_to_hdf5:   [10/68] Adding track ENCFF599VAD to HDF5 file.
# 2025-04-09 10:40:50,528::INFO::add_encode_tracks_to_hdf5:   [11/68] Adding track ENCFF921FOC to HDF5 file.
# 2025-04-09 10:40:50,530::INFO::add_encode_tracks_to_hdf5:   [12/68] Adding track ENCFF134OLO to HDF5 file.
# 2025-04-09 10:40:50,532::INFO::add_encode_tracks_to_hdf5:   [13/68] Adding track ENCFF218XJQ to HDF5 file.
# 2025-04-09 10:40:50,534::INFO::add_encode_tracks_to_hdf5:   [14/68] Adding track ENCFF902LSI to HDF5 file.
# 2025-04-09 10:40:50,536::INFO::add_encode_tracks_to_hdf5:   [15/68] Adding track ENCFF792DLB to HDF5 file.
# 2025-04-09 10:40:50,538::INFO::add_encode_tracks_to_hdf5:   [16/68] Adding track ENCFF414FEJ to HDF5 file.
# 2025-04-09 10:40:50,540::INFO::add_encode_tracks_to_hdf5:   [17/68] Adding track ENCFF830YRD to HDF5 file.
# 2025-04-09 10:40:50,542::INFO::add_encode_tracks_to_hdf5:   [18/68] Adding track ENCFF168UFN to HDF5 file.
# 2025-04-09 10:40:50,544::INFO::add_encode_tracks_to_hdf5:   [19/68] Adding track ENCFF347CQB to HDF5 file.
# 2025-04-09 10:40:50,546::INFO::add_encode_tracks_to_hdf5:   [20/68] Adding track ENCFF034CTK to HDF5 file.
# 2025-04-09 10:40:50,548::INFO::add_encode_tracks_to_hdf5:   [21/68] Adding track ENCFF295CPY to HDF5 file.
# 2025-04-09 10:40:50,550::INFO::add_encode_tracks_to_hdf5:   [22/68] Adding track ENCFF256WHR to HDF5 file.
# 2025-04-09 10:40:50,552::INFO::add_encode_tracks_to_hdf5:   [23/68] Adding track ENCFF884OMU to HDF5 file.
# 2025-04-09 10:40:50,554::INFO::add_encode_tracks_to_hdf5:   [24/68] Adding track ENCFF296NOR to HDF5 file.
# 2025-04-09 10:40:50,556::INFO::add_encode_tracks_to_hdf5:   [25/68] Adding track ENCFF435MWB to HDF5 file.
# 2025-04-09 10:40:50,558::INFO::add_encode_tracks_to_hdf5:   [26/68] Adding track ENCFF088KUT to HDF5 file.
# 2025-04-09 10:40:50,560::INFO::add_encode_tracks_to_hdf5:   [27/68] Adding track ENCFF853JHP to HDF5 file.
# 2025-04-09 10:40:50,562::INFO::add_encode_tracks_to_hdf5:   [28/68] Adding track ENCFF591RWC to HDF5 file.
# 2025-04-09 10:40:50,564::INFO::add_encode_tracks_to_hdf5:   [29/68] Adding track ENCFF885JYJ to HDF5 file.
# 2025-04-09 10:40:50,565::INFO::add_encode_tracks_to_hdf5:   [30/68] Adding track ENCFF087SNY to HDF5 file.
# 2025-04-09 10:40:50,567::INFO::add_encode_tracks_to_hdf5:   [31/68] Adding track ENCFF193MIZ to HDF5 file.
# 2025-04-09 10:40:50,568::INFO::add_encode_tracks_to_hdf5:   [32/68] Adding track ENCFF760SNB to HDF5 file.
# 2025-04-09 10:40:50,570::INFO::add_encode_tracks_to_hdf5:   [33/68] Adding track ENCFF892JDN to HDF5 file.
# 2025-04-09 10:40:50,571::INFO::add_encode_tracks_to_hdf5:   [34/68] Adding track ENCFF765HYA to HDF5 file.
# 2025-04-09 10:40:50,573::INFO::add_encode_tracks_to_hdf5:   [35/68] Adding track ENCFF788JSC to HDF5 file.
# 2025-04-09 10:40:50,574::INFO::add_encode_tracks_to_hdf5:   [36/68] Adding track ENCFF694IFY to HDF5 file.
# 2025-04-09 10:40:50,682::INFO::process_entry:   Loading signal for track: ENCFF402DAY
# 2025-04-09 10:40:50,682::INFO::add_encode_tracks_to_hdf5:   [37/68] Adding track ENCFF158WCY to HDF5 file.
# 2025-04-09 10:40:50,924::INFO::process_entry:   Loading signal for track: ENCFF926KDG
# 2025-04-09 10:40:50,924::INFO::add_encode_tracks_to_hdf5:   [38/68] Adding track ENCFF190AJB to HDF5 file.
# 2025-04-09 10:40:58,852::INFO::process_entry:   Loading signal for track: ENCFF653TLI
# 2025-04-09 10:40:58,853::INFO::add_encode_tracks_to_hdf5:   [39/68] Adding track ENCFF893HGX to HDF5 file.
# 2025-04-09 10:41:06,773::INFO::process_entry:   Loading signal for track: ENCFF959DIS
# 2025-04-09 10:41:10,649::INFO::process_entry:   Loading signal for track: ENCFF975SNY
# 2025-04-09 10:41:14,725::INFO::process_entry:   Loading signal for track: ENCFF859UUZ
# 2025-04-09 10:41:19,217::INFO::process_entry:   Loading signal for track: ENCFF020CWJ
# 2025-04-09 10:41:23,780::INFO::process_entry:   Loading signal for track: ENCFF220LVT
# 2025-04-09 10:41:23,780::INFO::add_encode_tracks_to_hdf5:   [40/68] Adding track ENCFF175MGD to HDF5 file.
# 2025-04-09 10:41:23,781::INFO::process_entry:   Loading signal for track: ENCFF826PFD
# 2025-04-09 10:41:28,153::INFO::process_entry:   Loading signal for track: ENCFF786OUD
# 2025-04-09 10:41:28,153::INFO::add_encode_tracks_to_hdf5:   [41/68] Adding track ENCFF373LYP to HDF5 file.
# 2025-04-09 10:41:32,078::INFO::process_entry:   Loading signal for track: ENCFF555QTG
# 2025-04-09 10:41:36,779::INFO::process_entry:   Loading signal for track: ENCFF264QTV
# 2025-04-09 10:41:40,617::INFO::process_entry:   Loading signal for track: ENCFF832EOA
# 2025-04-09 10:41:44,902::INFO::process_entry:   Loading signal for track: ENCFF014CKV
# 2025-04-09 10:41:48,741::INFO::process_entry:   Loading signal for track: ENCFF892ETR
# 2025-04-09 10:41:52,587::INFO::add_encode_tracks_to_hdf5:   [42/68] Adding track ENCFF301EPC to HDF5 file.
# 2025-04-09 10:41:56,513::INFO::process_entry:   Loading signal for track: ENCFF979VKE
# 2025-04-09 10:41:56,514::INFO::process_entry:   Loading signal for track: ENCFF637YHM
# 2025-04-09 10:42:05,680::INFO::process_entry:   Loading signal for track: ENCFF217MWA
# 2025-04-09 10:42:10,084::INFO::process_entry:   Loading signal for track: ENCFF966FLQ
# 2025-04-09 10:42:13,983::INFO::add_encode_tracks_to_hdf5:   [43/68] Adding track ENCFF537CQL to HDF5 file.
# 2025-04-09 10:42:13,984::INFO::process_entry:   Loading signal for track: ENCFF115QAJ
# 2025-04-09 10:42:13,985::INFO::process_entry:   Loading signal for track: ENCFF523KXW
# 2025-04-09 10:42:18,254::INFO::process_entry:   Loading signal for track: ENCFF495UDL
# 2025-04-09 10:42:22,032::INFO::process_entry:   Loading signal for track: ENCFF690UGP
# 2025-04-09 10:42:22,033::INFO::add_encode_tracks_to_hdf5:   [44/68] Adding track ENCFF926KDG to HDF5 file.
# 2025-04-09 10:42:29,984::INFO::process_entry:   Loading signal for track: ENCFF915RCT
# 2025-04-09 10:42:34,756::INFO::add_encode_tracks_to_hdf5:   [45/68] Adding track ENCFF061JOB to HDF5 file.
# 2025-04-09 10:42:38,959::INFO::add_encode_tracks_to_hdf5:   [46/68] Adding track ENCFF402DAY to HDF5 file.
# 2025-04-09 10:42:57,102::INFO::add_encode_tracks_to_hdf5:   [47/68] Adding track ENCFF653TLI to HDF5 file.
# 2025-04-09 10:42:57,104::INFO::add_encode_tracks_to_hdf5:   [48/68] Adding track ENCFF975SNY to HDF5 file.
# 2025-04-09 10:42:57,106::INFO::add_encode_tracks_to_hdf5:   [49/68] Adding track ENCFF859UUZ to HDF5 file.
# 2025-04-09 10:42:57,107::INFO::add_encode_tracks_to_hdf5:   [50/68] Adding track ENCFF959DIS to HDF5 file.
# 2025-04-09 10:42:57,108::INFO::add_encode_tracks_to_hdf5:   [51/68] Adding track ENCFF020CWJ to HDF5 file.
# 2025-04-09 10:42:57,109::INFO::add_encode_tracks_to_hdf5:   [52/68] Adding track ENCFF786OUD to HDF5 file.
# 2025-04-09 10:42:57,110::INFO::add_encode_tracks_to_hdf5:   [53/68] Adding track ENCFF220LVT to HDF5 file.
# 2025-04-09 10:42:57,112::INFO::add_encode_tracks_to_hdf5:   [54/68] Adding track ENCFF826PFD to HDF5 file.
# 2025-04-09 10:42:57,113::INFO::add_encode_tracks_to_hdf5:   [55/68] Adding track ENCFF832EOA to HDF5 file.
# 2025-04-09 10:42:57,114::INFO::add_encode_tracks_to_hdf5:   [56/68] Adding track ENCFF264QTV to HDF5 file.
# 2025-04-09 10:42:57,116::INFO::add_encode_tracks_to_hdf5:   [57/68] Adding track ENCFF555QTG to HDF5 file.
# 2025-04-09 10:42:57,117::INFO::add_encode_tracks_to_hdf5:   [58/68] Adding track ENCFF014CKV to HDF5 file.
# 2025-04-09 10:42:57,118::INFO::add_encode_tracks_to_hdf5:   [59/68] Adding track ENCFF892ETR to HDF5 file.
# 2025-04-09 10:42:57,119::INFO::add_encode_tracks_to_hdf5:   [60/68] Adding track ENCFF966FLQ to HDF5 file.
# 2025-04-09 10:42:57,120::INFO::add_encode_tracks_to_hdf5:   [61/68] Adding track ENCFF217MWA to HDF5 file.
# 2025-04-09 10:42:57,121::INFO::add_encode_tracks_to_hdf5:   [62/68] Adding track ENCFF979VKE to HDF5 file.
# 2025-04-09 10:42:57,122::INFO::add_encode_tracks_to_hdf5:   [63/68] Adding track ENCFF637YHM to HDF5 file.
# 2025-04-09 10:42:57,124::INFO::add_encode_tracks_to_hdf5:   [64/68] Adding track ENCFF523KXW to HDF5 file.
# 2025-04-09 10:42:57,125::INFO::add_encode_tracks_to_hdf5:   [65/68] Adding track ENCFF115QAJ to HDF5 file.
# 2025-04-09 10:42:57,126::INFO::add_encode_tracks_to_hdf5:   [66/68] Adding track ENCFF495UDL to HDF5 file.
# 2025-04-09 10:42:57,127::INFO::add_encode_tracks_to_hdf5:   [67/68] Adding track ENCFF690UGP to HDF5 file.
# 2025-04-09 10:42:57,349::INFO::add_encode_tracks_to_hdf5:   [68/68] Adding track ENCFF915RCT to HDF5 file.
# 2025-04-09 10:42:57,352::INFO::add_encode_tracks_to_hdf5:   All tracks and metadata added successfully.
# 2025-04-09 10:42:57,353::INFO::main:   HDF5 file 'data/t-cell-jointdb.h5' created successfully with all data.
# 2025-04-09 10:42:57,353::INFO::main:   Finished joint PCA
