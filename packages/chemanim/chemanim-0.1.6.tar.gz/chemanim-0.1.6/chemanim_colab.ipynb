# %% [markdown]
# # Chemanim Video Rendering (GPU)
# Render chemistry and protein animations with GPU acceleration using [chemanim](https://pypi.org/project/chemanim/).

# %% [markdown]
# ## Step 1: Install System Dependencies

# %%
# System dependencies for OpenGL rendering
# !apt-get update -qq
# !apt-get install -y -qq xvfb libgl1-mesa-dev libglu1-mesa-dev freeglut3-dev mesa-utils libosmesa6-dev libglfw3 libglfw3-dev libcairo2-dev libpango1.0-dev ffmpeg
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Extracting templates from packages: 100%
# Selecting previously unselected package freeglut3:amd64.
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../00-freeglut3_2.8.1-6_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-6) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../01-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../02-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-core-dev:amd64.
# Preparing to unpack .../03-libglvnd-core-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-core-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libegl-dev:amd64.
# Preparing to unpack .../04-libegl-dev_1.4.0-1_amd64.deb ...
# Unpacking libegl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles1:amd64.
# Preparing to unpack .../05-libgles1_1.4.0-1_amd64.deb ...
# Unpacking libgles1:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgles-dev:amd64.
# Preparing to unpack .../06-libgles-dev_1.4.0-1_amd64.deb ...
# Unpacking libgles-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl-dev:amd64.
# Preparing to unpack .../07-libopengl-dev_1.4.0-1_amd64.deb ...
# Unpacking libopengl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libglvnd-dev:amd64.
# Preparing to unpack .../08-libglvnd-dev_1.4.0-1_amd64.deb ...
# Unpacking libglvnd-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl1-mesa-dev:amd64.
# Preparing to unpack .../09-libgl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libglu1-mesa:amd64.
# Preparing to unpack .../10-libglu1-mesa_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa:amd64 (9.0.2-1) ...
# Selecting previously unselected package libglu1-mesa-dev:amd64.
# Preparing to unpack .../11-libglu1-mesa-dev_9.0.2-1_amd64.deb ...
# Unpacking libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Selecting previously unselected package libxt-dev:amd64.
# Preparing to unpack .../12-libxt-dev_1%3a1.2.1-1_amd64.deb ...
# Unpacking libxt-dev:amd64 (1:1.2.1-1) ...
# Selecting previously unselected package freeglut3-dev:amd64.
# Preparing to unpack .../13-freeglut3-dev_2.8.1-6_amd64.deb ...
# Unpacking freeglut3-dev:amd64 (2.8.1-6) ...
# Selecting previously unselected package libdatrie-dev:amd64.
# Preparing to unpack .../14-libdatrie-dev_0.2.13-2_amd64.deb ...
# Unpacking libdatrie-dev:amd64 (0.2.13-2) ...
# Selecting previously unselected package libegl1-mesa-dev:amd64.
# Preparing to unpack .../15-libegl1-mesa-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libfribidi-dev:amd64.
# Preparing to unpack .../16-libfribidi-dev_1.0.8-2ubuntu3.1_amd64.deb ...
# Unpacking libfribidi-dev:amd64 (1.0.8-2ubuntu3.1) ...
# Selecting previously unselected package libglfw3:amd64.
# Preparing to unpack .../17-libglfw3_3.3.6-1_amd64.deb ...
# Unpacking libglfw3:amd64 (3.3.6-1) ...
# Selecting previously unselected package libglfw3-dev:amd64.
# Preparing to unpack .../18-libglfw3-dev_3.3.6-1_amd64.deb ...
# Unpacking libglfw3-dev:amd64 (3.3.6-1) ...
# Selecting previously unselected package libgraphite2-dev:amd64.
# Preparing to unpack .../19-libgraphite2-dev_1.3.14-1build2_amd64.deb ...
# Unpacking libgraphite2-dev:amd64 (1.3.14-1build2) ...
# Selecting previously unselected package libharfbuzz-icu0:amd64.
# Preparing to unpack .../20-libharfbuzz-icu0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libharfbuzz-gobject0:amd64.
# Preparing to unpack .../21-libharfbuzz-gobject0_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-gobject0:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libharfbuzz-dev:amd64.
# Preparing to unpack .../22-libharfbuzz-dev_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz-dev:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libthai-dev:amd64.
# Preparing to unpack .../23-libthai-dev_0.1.29-1build1_amd64.deb ...
# Unpacking libthai-dev:amd64 (0.1.29-1build1) ...
# Selecting previously unselected package pango1.0-tools.
# Preparing to unpack .../24-pango1.0-tools_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking pango1.0-tools (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpango1.0-dev:amd64.
# Preparing to unpack .../25-libpango1.0-dev_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpango1.0-dev:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libvulkan1:amd64.
# Preparing to unpack .../26-libvulkan1_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan1:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libvulkan-dev:amd64.
# Preparing to unpack .../27-libvulkan-dev_1.3.204.1-2_amd64.deb ...
# Unpacking libvulkan-dev:amd64 (1.3.204.1-2) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../28-libxrandr-dev_2%3a1.5.2-1build1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Selecting previously unselected package mesa-utils-bin:amd64.
# Preparing to unpack .../29-mesa-utils-bin_8.4.0-1ubuntu1_amd64.deb ...
# Unpacking mesa-utils-bin:amd64 (8.4.0-1ubuntu1) ...
# Selecting previously unselected package mesa-vulkan-drivers:amd64.
# Preparing to unpack .../30-mesa-vulkan-drivers_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libosmesa6:amd64.
# Preparing to unpack .../31-libosmesa6_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../32-libosmesa6-dev_23.2.1-1ubuntu3.1~22.04.3_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package libwayland-bin.
# Preparing to unpack .../33-libwayland-bin_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-bin (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package libwayland-dev:amd64.
# Preparing to unpack .../34-libwayland-dev_1.20.0-1ubuntu0.1_amd64.deb ...
# Unpacking libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Selecting previously unselected package mesa-utils.
# Preparing to unpack .../35-mesa-utils_8.4.0-1ubuntu1_amd64.deb ...
# Unpacking mesa-utils (8.4.0-1ubuntu1) ...
# Setting up libglfw3:amd64 (3.3.6-1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up freeglut3:amd64 (2.8.1-6) ...
# Setting up libglvnd-core-dev:amd64 (1.4.0-1) ...
# Setting up libfribidi-dev:amd64 (1.0.8-2ubuntu3.1) ...
# Setting up pango1.0-tools (1.50.6+ds-2ubuntu1) ...
# Setting up libharfbuzz-gobject0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libwayland-bin (1.20.0-1ubuntu0.1) ...
# Setting up libgraphite2-dev:amd64 (1.3.14-1build2) ...
# Setting up libxrandr-dev:amd64 (2:1.5.2-1build1) ...
# Setting up mesa-utils-bin:amd64 (8.4.0-1ubuntu1) ...
# Setting up libxt-dev:amd64 (1:1.2.1-1) ...
# Setting up libgles1:amd64 (1.4.0-1) ...
# Setting up libvulkan1:amd64 (1.3.204.1-2) ...
# Setting up libdatrie-dev:amd64 (0.2.13-2) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libglu1-mesa:amd64 (9.0.2-1) ...
# Setting up libopengl-dev:amd64 (1.4.0-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libosmesa6:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up mesa-vulkan-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libharfbuzz-dev:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libvulkan-dev:amd64 (1.3.204.1-2) ...
# Setting up libglfw3-dev:amd64 (3.3.6-1) ...
# Setting up libegl-dev:amd64 (1.4.0-1) ...
# Setting up libwayland-dev:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up mesa-utils (8.4.0-1ubuntu1) ...
# Setting up libglu1-mesa-dev:amd64 (9.0.2-1) ...
# Setting up libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libthai-dev:amd64 (0.1.29-1build1) ...
# Setting up libgles-dev:amd64 (1.4.0-1) ...
# Setting up libglvnd-dev:amd64 (1.4.0-1) ...
# Setting up libpango1.0-dev:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libgl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libegl1-mesa-dev:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up freeglut3-dev:amd64 (2.8.1-6) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link

# %% [markdown]
# ## Step 2: Install Python Packages

# %%
# Install manimgl first (has complex dependencies)
# !pip install manimgl

# Install chemanim with bio dependencies
# !pip install chemanim[all] --upgrade

print('\n✓ Installation complete!')
# Out:
# Collecting manimgl
#   Downloading manimgl-1.7.2-py3-none-any.whl.metadata (8.2 kB)
# Collecting addict (from manimgl)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting appdirs (from manimgl)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: colour in /usr/local/lib/python3.12/dist-packages (from manimgl) (0.1.5)
# Collecting diskcache (from manimgl)
#   Downloading diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# Collecting ipython>=8.18.0 (from manimgl)
#   Downloading ipython-9.8.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting isosurfaces (from manimgl)
#   Downloading isosurfaces-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: fontTools in /usr/local/lib/python3.12/dist-packages (from manimgl) (4.61.1)
# Collecting manimpango>=0.6.0 (from manimgl)
#   Downloading manimpango-0.6.1.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 46.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mapbox-earcut (from manimgl)
#   Downloading mapbox_earcut-2.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from manimgl) (3.10.0)
# Collecting moderngl (from manimgl)
#   Downloading moderngl-5.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Collecting moderngl_window (from manimgl)
#   Downloading moderngl_window-3.1.1-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from manimgl) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from manimgl) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from manimgl) (0.25.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from manimgl) (2.19.2)
# Requirement already satisfied: PyOpenGL in /usr/local/lib/python3.12/dist-packages (from manimgl) (3.1.10)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from manimgl) (1.11.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from manimgl) (6.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from manimgl) (13.9.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from manimgl) (1.16.3)
# Collecting screeninfo (from manimgl)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting skia-pathops (from manimgl)
#   Downloading skia_pathops-0.9.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.5 kB)
# Collecting svgelements>=1.8.1 (from manimgl)
#   Downloading svgelements-1.9.6-py2.py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from manimgl) (1.14.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from manimgl) (4.67.1)
# Collecting validators (from manimgl)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl) (4.4.2)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=8.18.0->manimgl)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.1 (from ipython>=8.18.0->manimgl)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl) (3.0.52)
# Collecting stack_data>=0.6.0 (from ipython>=8.18.0->manimgl)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=8.18.0->manimgl)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->manimgl) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->manimgl) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->manimgl) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->manimgl) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->manimgl) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->manimgl) (2.9.0.post0)
# Collecting glcontext>=3.0.0 (from moderngl->manimgl)
#   Downloading glcontext-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Collecting pyglet>=2.0.0 (from moderngl_window->manimgl)
#   Downloading pyglet-2.1.11-py3-none-any.whl.metadata (7.7 kB)
# Collecting pyglm<3,>=2.7.0 (from moderngl_window->manimgl)
#   Downloading pyglm-2.8.3-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->manimgl) (4.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->manimgl) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.1->ipython>=8.18.0->manimgl) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->manimgl) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=8.18.0->manimgl) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.18.0->manimgl) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->manimgl) (1.17.0)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=8.18.0->manimgl)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=8.18.0->manimgl)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=8.18.0->manimgl)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading manimgl-1.7.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.2/231.2 kB 17.2 MB/s eta 0:00:00
# Downloading ipython-9.8.0-py3-none-any.whl (621 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 621.4/621.4 kB 4.7 MB/s eta 0:00:00
# Downloading svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 7.4 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diskcache-5.6.3-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.0 MB/s eta 0:00:00
# Downloading isosurfaces-0.1.2-py3-none-any.whl (11 kB)
# Downloading mapbox_earcut-2.0.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 3.7 MB/s eta 0:00:00
# Downloading moderngl-5.12.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 20.4 MB/s eta 0:00:00
# Downloading moderngl_window-3.1.1-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.4/382.4 kB 23.3 MB/s eta 0:00:00
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading skia_pathops-0.9.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.3 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 3.2 MB/s eta 0:00:00
# Downloading glcontext-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.1 MB/s eta 0:00:00
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 75.0 MB/s eta 0:00:00
# Downloading pyglet-2.1.11-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.1 MB/s eta 0:00:00
# Downloading pyglm-2.8.3-cp312-cp312-manylinux_2_34_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 115.5 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 5.7 MB/s eta 0:00:00
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Building wheels for collected packages: manimpango
#   Building wheel for manimpango (pyproject.toml) ... done
#   Created wheel for manimpango: filename=manimpango-0.6.1-cp312-cp312-linux_x86_64.whl size=470353 sha256=1d9f40d26a5385d8a59f1301d9cd97395b22103a1fbfdb80e58c1086e4819e44
#   Stored in directory: /root/.cache/pip/wheels/16/12/15/2b8b37e4dd2e61b3e23176182a94e7d71f226d06240af8b9ec
# Successfully built manimpango
# Installing collected packages: svgelements, pyglm, pure-eval, glcontext, appdirs, addict, validators, traitlets, skia-pathops, screeninfo, pyglet, moderngl, mapbox-earcut, manimpango, jedi, isosurfaces, ipython-pygments-lexers, executing, diskcache, asttokens, stack_data, moderngl_window, ipython, manimgl
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 9.8.0 which is incompatible.
# Successfully installed addict-2.4.0 appdirs-1.4.4 asttokens-3.0.1 diskcache-5.6.3 executing-2.2.1 glcontext-3.0.0 ipython-9.8.0 ipython-pygments-lexers-1.1.1 isosurfaces-0.1.2 jedi-0.19.2 manimgl-1.7.2 manimpango-0.6.1 mapbox-earcut-2.0.0 moderngl-5.12.0 moderngl_window-3.1.1 pure-eval-0.2.3 pyglet-2.1.11 pyglm-2.8.3 screeninfo-0.8.1 skia-pathops-0.9.1 stack_data-0.6.3 svgelements-1.9.6 traitlets-5.14.3 validators-0.35.0
# Collecting chemanim[all]
#   Downloading chemanim-0.1.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting biopython (from chemanim[all])
#   Downloading biopython-1.86-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from chemanim[all]) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from chemanim[all]) (2.0.2)
# Collecting pubchempy (from chemanim[all])
#   Downloading pubchempy-1.0.5-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from chemanim[all]) (2.32.4)
# Collecting biotite (from chemanim[all])
#   Downloading biotite-1.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting chemformula (from chemanim[all])
#   Downloading chemformula-1.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting chempy (from chemanim[all])
#   Downloading chempy-0.10.1-py2.py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: manimgl in /usr/local/lib/python3.12/dist-packages (from chemanim[all]) (1.7.2)
# Collecting py3dmol (from chemanim[all])
#   Downloading py3dmol-2.5.3-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting rdkit (from chemanim[all])
#   Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Collecting biotraj<2.0,>=1.0 (from biotite->chemanim[all])
#   Downloading biotraj-1.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (32 kB)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from biotite->chemanim[all]) (1.1.2)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from biotite->chemanim[all]) (25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->chemanim[all]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->chemanim[all]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->chemanim[all]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->chemanim[all]) (2025.11.12)
# Collecting casregnum>=1.1.2 (from chemformula->chemanim[all])
#   Downloading casregnum-1.1.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from chempy->chemanim[all]) (1.16.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from chempy->chemanim[all]) (3.10.0)
# Requirement already satisfied: sympy!=1.2,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from chempy->chemanim[all]) (1.14.0)
# Collecting quantities>=0.12.1 (from chempy->chemanim[all])
#   Downloading quantities-0.16.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting pyneqsys>=0.5.7 (from chempy->chemanim[all])
#   Downloading pyneqsys-0.5.7.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pyodesys>=0.14.5 (from chempy->chemanim[all])
#   Downloading pyodesys-0.14.5.tar.gz (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from chempy->chemanim[all]) (3.2.5)
# Collecting sym>=0.3.7 (from chempy->chemanim[all])
#   Downloading sym-0.3.7.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate in /usr/local/lib/python3.12/dist-packages (from chempy->chemanim[all]) (0.9.0)
# Requirement already satisfied: pulp>=1.6.8 in /usr/local/lib/python3.12/dist-packages (from chempy->chemanim[all]) (3.3.0)
# Collecting dot2tex>=2.11.3 (from chempy->chemanim[all])
#   Downloading dot2tex-2.11.3-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: addict in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (2.4.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (1.4.4)
# Requirement already satisfied: colour in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.1.5)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (5.6.3)
# Requirement already satisfied: ipython>=8.18.0 in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (9.8.0)
# Requirement already satisfied: isosurfaces in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.1.2)
# Requirement already satisfied: fontTools in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (4.61.1)
# Requirement already satisfied: manimpango>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.6.1)
# Requirement already satisfied: mapbox-earcut in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (2.0.0)
# Requirement already satisfied: moderngl in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (5.12.0)
# Requirement already satisfied: moderngl_window in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (3.1.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.25.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (2.19.2)
# Requirement already satisfied: PyOpenGL in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (3.1.10)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (1.11.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (6.0.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (13.9.4)
# Requirement already satisfied: screeninfo in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.8.1)
# Requirement already satisfied: skia-pathops in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.9.1)
# Requirement already satisfied: svgelements>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (1.9.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (4.67.1)
# Requirement already satisfied: validators in /usr/local/lib/python3.12/dist-packages (from manimgl->chemanim[all]) (0.35.0)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (4.4.2)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (3.0.52)
# Requirement already satisfied: stack_data>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=8.18.0->manimgl->chemanim[all]) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->chempy->chemanim[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->chempy->chemanim[all]) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->chempy->chemanim[all]) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->chempy->chemanim[all]) (2.9.0.post0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from pyodesys>=0.14.5->chempy->chemanim[all]) (6.5.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy!=1.2,>=1.1.1->chempy->chemanim[all]) (1.3.0)
# Requirement already satisfied: glcontext>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from moderngl->manimgl->chemanim[all]) (3.0.0)
# Requirement already satisfied: pyglet>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from moderngl_window->manimgl->chemanim[all]) (2.1.11)
# Requirement already satisfied: pyglm<3,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from moderngl_window->manimgl->chemanim[all]) (2.8.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->manimgl->chemanim[all]) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.18.1->ipython>=8.18.0->manimgl->chemanim[all]) (0.8.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->manimgl->chemanim[all]) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=8.18.0->manimgl->chemanim[all]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.18.0->manimgl->chemanim[all]) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->chempy->chemanim[all]) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.18.0->manimgl->chemanim[all]) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.18.0->manimgl->chemanim[all]) (3.0.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.12/dist-packages (from stack_data>=0.6.0->ipython>=8.18.0->manimgl->chemanim[all]) (0.2.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (6.5.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (25.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (5.9.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (7.4.9)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.6.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (6.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client<8,>=5.3.4->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.6.1->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (4.5.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (4.25.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (25.1.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.8.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (5.9.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.30.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (4.12.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.9.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (1.4.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->pyodesys>=0.14.5->chempy->chemanim[all]) (2025.3)
# Downloading biopython-1.86-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 56.2 MB/s eta 0:00:00
# Downloading biotite-1.5.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 MB 14.6 MB/s eta 0:00:00
# Downloading chemanim-0.1.4-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 5.2 MB/s eta 0:00:00
# Downloading chemformula-1.5.1-py3-none-any.whl (19 kB)
# Downloading chempy-0.10.1-py2.py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.3/230.3 kB 14.3 MB/s eta 0:00:00
# Downloading pubchempy-1.0.5-py3-none-any.whl (21 kB)
# Downloading py3dmol-2.5.3-py2.py3-none-any.whl (7.2 kB)
# Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 28.0 MB/s eta 0:00:00
# Downloading biotraj-1.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 49.7 MB/s eta 0:00:00
# Downloading casregnum-1.1.2-py3-none-any.whl (6.0 kB)
# Downloading dot2tex-2.11.3-py2.py3-none-any.whl (36 kB)
# Downloading quantities-0.16.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 7.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyneqsys, pyodesys, sym
#   Building wheel for pyneqsys (setup.py) ... done
#   Created wheel for pyneqsys: filename=pyneqsys-0.5.7-py2.py3-none-any.whl size=27266 sha256=7360666d89df06e723654ec24e64fab50cf3c74763d1f7b9842c11f9bb85f449
#   Stored in directory: /root/.cache/pip/wheels/08/b7/f0/7758574bed9afb4f51c2a92bce9dd8c40dc0a7aa7a78cf7b63
#   Building wheel for pyodesys (setup.py) ... done
#   Created wheel for pyodesys: filename=pyodesys-0.14.5-py2.py3-none-any.whl size=126359 sha256=c3087e500eb8e1a66339d44372fcd99df12f221005bdb93c7bf9c9fba64c994e
#   Stored in directory: /root/.cache/pip/wheels/80/c7/10/1b7910c45acec61c1dd8bb78c355fb4e1844b4994d750c6389
#   Building wheel for sym (setup.py) ... done
#   Created wheel for sym: filename=sym-0.3.7-py2.py3-none-any.whl size=22902 sha256=8ecd0b187bef225d92ee17ebfb26579fe3834f7864b3f3f519cce72d5c514746
#   Stored in directory: /root/.cache/pip/wheels/b0/de/3a/7d80ae2b115183cdb91d32bb59912e3fc0269f7f48c21d9d79
# Successfully built pyneqsys pyodesys sym
# Installing collected packages: py3dmol, sym, rdkit, quantities, pubchempy, dot2tex, casregnum, biopython, chemformula, chemanim, biotraj, pyneqsys, biotite, pyodesys, chempy
# Successfully installed biopython-1.86 biotite-1.5.0 biotraj-1.2.2 casregnum-1.1.2 chemanim-0.1.4 chemformula-1.5.1 chempy-0.10.1 dot2tex-2.11.3 pubchempy-1.0.5 py3dmol-2.5.3 pyneqsys-0.5.7 pyodesys-0.14.5 quantities-0.16.2 rdkit-2025.9.3 sym-0.3.7
#
# ✓ Installation complete!

# %%
# Start virtual display for headless rendering
import subprocess
import os

subprocess.Popen(['Xvfb', ':99', '-screen', '0', '1920x1080x24'])
os.environ['DISPLAY'] = ':99'
print('✓ Virtual display started')
# Out:
# ✓ Virtual display started

# %%
# Verify installation
from chemanim.bio import Protein
from chemanim.chem_object import ChemObject
print('✓ Chemanim imported successfully!')
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# ✓ Chemanim imported successfully!

# %% [markdown]
# ## Step 3: Create Your Animation
# Edit the cell below to customize your animation.

# %%
# %%writefile my_animation.py
"""ManimGL Demo: Hemoglobin Multi-Chain Protein
Showcases color schemes and render styles on a larger multi-chain protein.
Hemoglobin (2HHB) has 4 chains - 2 alpha and 2 beta subunits.
Each mode/color is shown with fade in/out transitions.
"""
from manimlib import *
from chemanim.bio import Protein
import os

class HemoglobinShowcase(Scene):
    def construct(self):
        # Camera Setup - Zoomed out significantly for large molecule
        frame = self.camera.frame
        frame.set_euler_angles(theta=30 * DEGREES, phi=70 * DEGREES)
        frame.scale(3.5)  # Zoom out significantly for hemoglobin

        # Title
        title = Text("Hemoglobin (4 Chains)", font_size=36).to_edge(UP)
        title.fix_in_frame()
        self.add(title)

        # Dynamic label
        info_label = Text("Loading...", font_size=24, color=YELLOW).next_to(title, DOWN)
        info_label.fix_in_frame()
        self.add(info_label)

        # Load Hemoglobin (2HHB - Human Deoxyhemoglobin)
        print("Fetching Hemoglobin (2HHB)...")
        try:
            mol = Protein.from_pdb_id("2HHB", download_dir="examples", include_hydrogens=False)
        except Exception as e:
            print(f"Fetch failed: {e}")
            return

        # Start with cartoon to show structure
        mol.apply_render_style("cartoon")
        mol.scale(1.5)
        mol.move_to(ORIGIN)
        mol.set_opacity(0)  # Start invisible
        self.add(mol)

        # Initial fade in
        new_label = Text("Cartoon - SSE Coloring", font_size=24, color=YELLOW).next_to(title, DOWN)
        new_label.fix_in_frame()
        self.play(
            Transform(info_label, new_label),
            FadeIn(mol),
            run_time=1.0
        )
        self.play(Rotate(mol, angle=90 * DEGREES, axis=UP), run_time=2)
        self.wait(0.3)

        # ===== COLOR SCHEMES DEMO =====
        color_schemes = [
            ("chain", "Color by Chain (4 different colors)"),
            ("amino_acid", "Color by Amino Acid Type"),
            ("rainbow", "Rainbow (N→C Terminus per Chain)"),
            ("hydrophobicity", "Hydrophobicity Scale"),
        ]

        for scheme_code, scheme_name in color_schemes:
            # Fade out current
            self.play(FadeOut(mol), run_time=0.5)

            # Update label
            new_label = Text(scheme_name, font_size=24, color=YELLOW).next_to(title, DOWN)
            new_label.fix_in_frame()
            self.play(Transform(info_label, new_label), run_time=0.3)

            # Apply color scheme while hidden
            print(f"Applying color scheme: {scheme_code}")
            mol.set_color_scheme(scheme_code)

            # Fade in with new colors
            self.play(FadeIn(mol), run_time=0.5)
            self.play(Rotate(mol, angle=90 * DEGREES, axis=UP), run_time=2)
            self.wait(0.3)

        # ===== RENDER STYLES DEMO =====
        styles = [
            ("ribbon", "Ribbon Style", "sse"),
            ("trace", "Backbone Trace", "sse"),
            ("ball_and_stick", "Ball and Stick", "chain"),
            ("sticks", "Sticks", "chain"),
        ]

        for style_code, style_name, color_scheme in styles:
            # Fade out current
            self.play(FadeOut(mol), run_time=0.5)

            # Update label
            new_label = Text(style_name, font_size=24, color=YELLOW).next_to(title, DOWN)
            new_label.fix_in_frame()
            self.play(Transform(info_label, new_label), run_time=0.3)

            # Apply style while hidden
            print(f"Applying style: {style_code}")
            mol.apply_render_style(style_code)
            mol.set_color_scheme(color_scheme)

            # Fade in with new style
            self.play(FadeIn(mol), run_time=0.5)
            self.play(Rotate(mol, angle=90 * DEGREES, axis=UP), run_time=2)
            self.wait(0.3)

        # Final - back to cartoon with chain coloring
        self.play(FadeOut(mol), run_time=0.5)

        new_label = Text("Cartoon - Chain Coloring", font_size=24, color=GREEN).next_to(title, DOWN)
        new_label.fix_in_frame()
        self.play(Transform(info_label, new_label), run_time=0.3)

        mol.apply_render_style("cartoon")
        mol.set_color_scheme("chain")

        self.play(FadeIn(mol), run_time=0.5)
        self.play(Rotate(mol, angle=360 * DEGREES, axis=UP), run_time=5)

        # Final fade out
        self.play(FadeOut(mol), run_time=1.0)
# Out:
# Writing my_animation.py

# %% [markdown]
# ## Step 4: Render Video

# %%
# Render the animation
# !python -m manimlib my_animation.py ProteinShowcase -w --video_dir ./output
# Out:
# ManimGL v1.7.2
# HemoglobinShowcase.mp4                  : : 0it [00:00, ?it/s]Fetching Hemoglobin (2HHB)...
# Fetch failed: cannot import name 'fetch_pdb_file' from 'chemanim.connect' (/usr/local/lib/python3.12/dist-packages/chemanim/connect.py)
# [01:00:50 PM] INFO     File ready at                    ]8;id=271493;file:///usr/local/lib/python3.12/dist-packages/manimlib/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=536110;file:///usr/local/lib/python3.12/dist-packages/manimlib/scene/scene_file_writer.py#341\341]8;;\
#                        /content/output/HemoglobinShowca
#                        se.mp4

# %% [markdown]
# ## Step 5: Find and Download Video

# %%
# Debug: Show what files exist
print('=== Current directory files ===')
# !ls -la
print('\n=== Looking for video directories ===')
# !find . -type d \( -name 'videos' -o -name 'output' -o -name 'media' \) 2>/dev/null
print('\n=== All .mp4 files ===')
# !find . -name '*.mp4' 2>/dev/null
# !find /root -name '*.mp4' 2>/dev/null
# !find /tmp -name '*.mp4' 2>/dev/null
# Out:
# === Current directory files ===
# total 32
# drwxr-xr-x 1 root root 4096 Dec 30 13:00 .
# drwxr-xr-x 1 root root 4096 Dec 30 12:58 ..
# drwxr-xr-x 4 root root 4096 Dec 11 14:34 .config
# -rw-r--r-- 1 root root 4424 Dec 30 13:00 my_animation.py
# drwxr-xr-x 2 root root 4096 Dec 30 13:00 output
# drwxr-xr-x 2 root root 4096 Dec 30 13:00 __pycache__
# drwxr-xr-x 1 root root 4096 Dec 11 14:34 sample_data
#
# === Looking for video directories ===
# ./output
#
# === All .mp4 files ===
# ./output/HemoglobinShowcase.mp4

# %%
import glob
import os
from google.colab import files

# Search in all common ManimGL output locations
search_patterns = [
    '*.mp4',
    'output/**/*.mp4',
    'videos/**/*.mp4',
    'media/**/*.mp4',
    '/content/**/*.mp4',
    '/root/**/*.mp4',
]

videos = []
for pattern in search_patterns:
    try:
        found = glob.glob(pattern, recursive=True)
        videos.extend(found)
    except:
        pass

# Remove duplicates
videos = list(set(videos))
print(f'Found {len(videos)} video(s): {videos}')

if videos:
    for v in videos:
        print(f'Downloading {v}...')
        files.download(v)
else:
    print('\n⚠️ No videos found!')
    print('Check the Step 4 output for errors.')
    print('If rendering succeeded, try manually: !find / -name \"*.mp4\" 2>/dev/null')
# Out:
# Found 2 video(s): ['output/HemoglobinShowcase.mp4', '/content/output/HemoglobinShowcase.mp4']
# Downloading output/HemoglobinShowcase.mp4...
# Downloading /content/output/HemoglobinShowcase.mp4...
